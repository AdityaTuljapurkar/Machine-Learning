# %%
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as ply 
import seaborn as sns 

df = sns.load_dataset('car_crashes')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     str
# dtypes: float64(7), str(1)
# memory usage: 3.3 KB

# %%
sns.pairplot(df,hue="abbrev")

# %%
df.describe()
df.info(
)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     str
# dtypes: float64(7), str(1)
# memory usage: 3.3 KB

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='crest')
# Out:
# <Axes: >

# %%
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     str
# dtypes: float64(7), str(1)
# memory usage: 3.3 KB

# %%
# sns.pairplot(df,hue='abbrev',corner=False)
df.info()
df.describe()
# print(df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     str
# dtypes: float64(7), str(1)
# memory usage: 3.3 KB
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# ...

# %%
# abrv vs total; 
import pandas as pd 

x = pd.DataFrame(df['abbrev'],columns=df['abbrev'])
y = pd.Series(df['total'])

# %%
sns.barplot(data=df, x='abbrev', y='total')
plt.xticks(rotation = 90)
plt.tight_layout()

# %%
x.count()
# Out:
# abbrev
# AL    0
# AK    0
# AZ    0
# AR    0
# CA    0
# CO    0
# CT    0
# DE    0
# DC    0
# FL    0
# GA    0
# HI    0
# ID    0
# IL    0
# IN    0
# IA    0
# KS    0
# KY    0
# LA    0
# ME    0
# MD    0
# MA    0
# MI    0
# MN    0
# MS    0
# MO    0
# MT    0
# NE    0
# NV    0
# NH    0
# NJ    0
# NM    0
# NY    0
# NC    0
# ND    0
# OH    0
# OK    0
# OR    0
# PA    0
# RI    0
# SC    0
# SD    0
# TN    0
# TX    0
# UT    0
# VT    0
# VA    0
# WA    0
# WV    0
# WI    0
# WY    0
# dtype: int64

# %%
df1 = df.drop(columns='abbrev')
df1.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
sns.heatmap(df1.corr(),annot=True,cmap='crest')
# Out:
# <Axes: >

# %%
df1['risk_bin'] = pd.cut(df1['total'],bins= [0,10,19,21],labels=['low','mid','high'],)
sns.pairplot(df1,hue='risk_bin',corner=False)

# %%
sns.heatmap( df1.select_dtypes(include='number').corr(),annot=True)
# Out:
# <Axes: >

# %%
X = df.drop(columns=['total'])   # features
X = pd.get_dummies(X, columns=['abbrev'])
Y = df['total']                  # target

# %%
print(X.shape, y.shape)
# Out:
# (51, 57) (51,)

# %%
from sklearn.model_selection import train_test_split 
x_train , x_test ,y_train, y_test = train_test_split(X,Y,test_size=0.4,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
x_train = std.fit_transform(x_train)
x_test  = std.fit_transform(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor

tree = DecisionTreeRegressor(max_depth=45, random_state=45)
tree.fit(x_train, y_train)
y_pred_tree = tree.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt


plt.scatter(y_test,y_pred_tree)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Decision Tree Regressor: Actual vs Predicted")
lims = [min(y_test.min(), y_pred_tree.min()), max(y_test.max(), y_pred_tree.max())]
plt.plot(lims, lims, 'r--')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_52626/3033577407.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
