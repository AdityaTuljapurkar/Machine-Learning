# %% [markdown]
# <h2>Steps for ML - </h2>
# <ol>
# <li> Data collections
# <li> Data Processing
# <li> train and test split
# <li> Model Training
# <li> Model evaluation
# <li> Inference
# </ol>

# %% [markdown]
# Data Colloection

# %%
from sklearn.datasets import load_iris 
iris = load_iris()

# %%
import pandas as pd 
x = pd.DataFrame(iris.data,columns= iris.feature_names)
y = pd.Series(iris.target)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Length: 150, dtype: int64

# %%
df = x.copy()
df['target']=y
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
import seaborn as sns  

sns.countplot(
    df ,
    x=iris.target,

)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Pair wise feature relationship

# %%
sns.pairplot(df,hue='target',corner=False)

# %% [markdown]
# Correlatonal heatmap

# %%
import matplotlib.pyplot as plt
sns.heatmap(df.corr(), annot=True, cmap
="crest")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# Data Processing

# %%
from sklearn.model_selection import train_test_split 
x_train ,x_test, y_train ,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler =  StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# Machine learnong models : <br>
# <u>
# k-learnong-model :</u>  <br>
# in this model you complare your data with the nearst data sample and by looking its domenent caractersitics you find its conclution

# %%
from sklearn.neighbors import KNeighborsClassifier

knn =  KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred_knn = knn.predict(x_test)

# %% [markdown]
# Decision Tree : here we compare and pridect the data by comapare if though buch of conditions
#     N <br>
# true/     \ flase<br>
# Cf1         Cf2 <br>

# %%
from sklearn.tree import DecisionTreeClassifier 
tree =  DecisionTreeClassifier(max_depth=3,random_state=43)
tree.fit(x_train,y_train)
y_pred_tree = tree.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

def plot_confusion(y_true, y_pred, title) :
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(title)
    plt.show()

plot_confusion(y_test, y_pred_knn, "KNN Confusion Matrix")
plot_confusion(y_test, y_pred_tree, "Decision Tree Confusion Matrix")
